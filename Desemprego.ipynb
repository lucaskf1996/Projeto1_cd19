# %% [markdown]
# # Projeto 1 - Ciência dos Dados

# %% [markdown]
# Nome: Lucas Keichi Fukada

# %% [markdown]
# ## Pergunta (s) a ser respondida

# %% [markdown]
# A entrada e saída da Venezuela no MERCOSUL fez diferença para a porcentagem de população empregada?

# %% [markdown]
# ## Explicação da hipótese e mecanismo

# %% [markdown]
# As pessoas podem conseguir emprego por conta da possibilidade de receber a permissão de residência facilitada nos outros países desde que ambos estejam incluídos no bloco econômico Sul Amerciano, as taxas de pessoas empregadas deveriam receber alguma alteração.
#
# https://www.weforum.org/agenda/2015/09/how-trade-liberalisation-affects-unemployment-and-real-income/

# %% [markdown]
# ## Bases de dados usadas

# %% [markdown]
# https://www.ilo.org/ilostat/faces/oracle/webcenter/portalapp/pagehierarchy/Page3.jspx?MBI_ID=7&_afrLoop=3055538129811766&_afrWindowMode=0&_afrWindowId=mdmwh3h32_1#!%40%40%3F_afrWindowId%3Dmdmwh3h32_1%26_afrLoop%3D3055538129811766%26MBI_ID%3D7%26_afrWindowMode%3D0%26_adf.ctrl-state%3Dmdmwh3h32_45 - Porcentagem de empregados acima de 15 anos.

# %% [markdown]
# ## Análise de dados

# %% [markdown]
# Para analisar tal efeito, serão manipulados os dados sobre a quantidade de pessoas empregadas, oferecidos pela Organização Internacional do Trabalho, especificamente perto dos anos de entrada e suspensão da Venezuela. Também serão analisados outros países, nesse caso os outros integrantes dos BRICS por apresentarem algumas características similares.

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import pandas as pd

emprego = pd.read_excel("employmentratio.xlsx")

# %%
emprego = emprego.set_index("Reference area")
emprego_mercosul = emprego.loc[["Brazil", "Argentina", "Uruguay", "Paraguay", "Venezuela"]]
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:2: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike

# %%
emprego_mercosul = emprego_mercosul[emprego_mercosul.Age == "15+"]
emprego_mercosul.time = emprego_mercosul.Time.astype(dtype="int64")
emprego_mercosul
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#                  Source type  Age    Time       Male     Female  Total
# Reference area
# Brazil          ILO estimate  15+  2000.0  43307.834  27508.702  57.81
# Brazil          ILO estimate  15+  2001.0  43957.302  28858.944  58.20
# Brazil          ILO estimate  15+  2002.0  44989.912  30382.597  58.98
# Brazil          ILO estimate  15+  2003.0  45511.004  30922.585  58.59
# Brazil          ILO estimate  15+  2004.0  47146.580  32420.529  59.79
# Brazil          ILO estimate  15+  2005.0  47918.255  33525.438  60.06
# Brazil          ILO estimate  15+  2006.0  48887.603  34432.119  60.30
# Brazil          ILO estimate  15+  2007.0  49702.407  34986.486  60.23
# Brazil          ILO estimate  15+  2008.0  51041.320  35996.715  60.87
# Brazil          ILO estimate  15+  2009.0  51312.025  36342.635  60.30
# Brazil          ILO estimate  15+  2010.0  51958.421  36397.522  59.79
# Brazil          ILO estimate  15+  2011.0  52560.361  36429.074  59.24
# Brazil          ILO estimate  15+  2012.0  53325.706  37813.489  59.72
# Brazil          ILO estimate  15+  2013.0  54132.096  38455.777  59.74
# Brazil          ILO estimate  15+  2014.0  54655.521  39237.704  59.68
# Brazil          ILO estimate  15+  2015.0  54315.905  39355.072  58.69
# Brazil          ILO estimate  15+  2016.0  52901.987  38328.468  56.42
# Brazil          ILO estimate  15+  2017.0  52638.783  38875.173  55.88
# Brazil          ILO estimate  15+  2018.0  53323.567  39409.727  55.92
# Brazil          ILO estimate  15+  2019.0  54164.007  39772.216  55.99
# Brazil          ILO estimate  15+  2020.0  54933.991  40276.409  56.13
# Brazil          ILO estimate  15+  2021.0  55517.287  40733.365  56.15
# Brazil          ILO estimate  15+  2022.0  55867.618  41170.728  56.07
# Argentina       ILO estimate  15+  2000.0   8318.578   5825.722  53.00
# Argentina       ILO estimate  15+  2001.0   8107.215   5808.007  51.39
# Argentina       ILO estimate  15+  2002.0   7939.916   5637.143  49.44
# Argentina       ILO estimate  15+  2003.0   8714.432   5874.251  52.41
# Argentina       ILO estimate  15+  2004.0   9059.177   6159.072  53.93
# Argentina       ILO estimate  15+  2005.0   9381.165   6327.642  54.91
# Argentina       ILO estimate  15+  2006.0   9680.116   6564.012  56.05
# ...                      ...  ...     ...        ...        ...    ...
# Uruguay         ILO estimate  15+  2016.0    895.877    720.765  59.59
# Uruguay         ILO estimate  15+  2017.0    893.629    720.027  59.13
# Uruguay         ILO estimate  15+  2018.0    900.908    724.064  59.21
# Uruguay         ILO estimate  15+  2019.0    908.459    729.027  59.33
# Uruguay         ILO estimate  15+  2020.0    915.599    734.005  59.45
# Uruguay         ILO estimate  15+  2021.0    921.442    738.421  59.51
# Uruguay         ILO estimate  15+  2022.0    927.231    743.050  59.58
# Paraguay        ILO estimate  15+  2000.0   1309.653    749.230  62.85
# Paraguay        ILO estimate  15+  2001.0   1348.527    769.206  62.91
# Paraguay        ILO estimate  15+  2002.0   1392.095    792.416  63.10
# Paraguay        ILO estimate  15+  2003.0   1429.920    844.209  63.87
# Paraguay        ILO estimate  15+  2004.0   1508.470    950.727  67.24
# Paraguay        ILO estimate  15+  2005.0   1553.934    975.732  67.44
# Paraguay        ILO estimate  15+  2006.0   1568.545    927.061  64.94
# Paraguay        ILO estimate  15+  2007.0   1622.940    986.747  66.44
# Paraguay        ILO estimate  15+  2008.0   1664.757   1008.472  66.69
# Paraguay        ILO estimate  15+  2009.0   1687.492   1061.439  67.19
# Paraguay        ILO estimate  15+  2010.0   1707.137   1044.005  65.83
# Paraguay        ILO estimate  15+  2011.0   1723.918   1092.151  66.02
# Paraguay        ILO estimate  15+  2012.0   1798.733   1226.135  69.40
# Paraguay        ILO estimate  15+  2013.0   1809.400   1227.066  68.16
# Paraguay        ILO estimate  15+  2014.0   1833.235   1170.819  66.03
# Paraguay        ILO estimate  15+  2015.0   1863.297   1216.850  66.40
# Paraguay        ILO estimate  15+  2016.0   1924.214   1224.350  66.62
# Paraguay        ILO estimate  15+  2017.0   1964.124   1269.932  67.25
# Paraguay        ILO estimate  15+  2018.0   1995.927   1294.046  67.32
# Paraguay        ILO estimate  15+  2019.0   2026.819   1323.187  67.46
# Paraguay        ILO estimate  15+  2020.0   2058.140   1351.245  67.57
# Paraguay        ILO estimate  15+  2021.0   2085.365   1377.769  67.59
# Paraguay        ILO estimate  15+  2022.0   2110.181   1402.963  67.51
#
# [92 rows x 6 columns]

# %%
emprego_mercosul = emprego_mercosul.pivot_table(values='Total', index=emprego_mercosul.index, columns='Time', aggfunc='first')
emprego_mercosul
# Out:
# Time            2000.0  2001.0  2002.0  2003.0  2004.0  2005.0  2006.0  \
# Reference area
# Argentina        53.00   51.39   49.44   52.41   53.93   54.91   56.05
# Brazil           57.81   58.20   58.98   58.59   59.79   60.06   60.30
# Paraguay         62.85   62.91   63.10   63.87   67.24   67.44   64.94
# Uruguay          54.41   55.35   54.63   53.92   54.13   54.99   56.78
#
# Time            2007.0  2008.0  2009.0   ...    2013.0  2014.0  2015.0  \
# Reference area                           ...
# Argentina        56.38   56.09   55.94   ...     56.12   55.51   55.55
# Brazil           60.23   60.87   60.30   ...     59.74   59.68   58.69
# Paraguay         66.44   66.69   67.19   ...     68.16   66.03   66.40
# Uruguay          58.85   60.25   60.69   ...     60.70   61.09   60.08
#
# Time            2016.0  2017.0  2018.0  2019.0  2020.0  2021.0  2022.0
# Reference area
# Argentina        55.56   55.57   54.76   54.33   54.10   54.02   53.90
# Brazil           56.42   55.88   55.92   55.99   56.13   56.15   56.07
# Paraguay         66.62   67.25   67.32   67.46   67.57   67.59   67.51
# Uruguay          59.59   59.13   59.21   59.33   59.45   59.51   59.58
#
# [4 rows x 23 columns]

# %% [markdown]
# ## Brasil

# %%
emprego_brazil = emprego_mercosul.loc["Brazil",[2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018]]
emprego_brazil.plot.line(grid = True)

# %% [markdown]
# ## Argentina

# %%
emprego_argentina = emprego_mercosul.loc["Argentina",[2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018]]
emprego_argentina.plot.line(grid = True)

# %% [markdown]
# ## Paraguai

# %%
emprego_paraguay = emprego_mercosul.loc["Paraguay",[2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018]]
emprego_paraguay.plot.line(grid = True)

# %% [markdown]
# ## Uruguai

# %%
emprego_uruguay = emprego_mercosul.loc["Uruguay",[2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018]]
emprego_uruguay.plot.line(grid = True)

# %% [markdown]
# ## MERCOSUL

# %%
paises = ["Brazil", "Paraguay", "Uruguay", "Argentina"]
for i in paises:
    emprego_mercosul.loc[i, [2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012]].plot(label = i)
plt.legend()
plt.grid(True)
plt.show()

# %%
emprego_mercosul = emprego_mercosul.transpose()
emprego_mercosul
# Out:
# Reference area  Argentina  Brazil  Paraguay  Uruguay
# Time
# 2000.0              53.00   57.81     62.85    54.41
# 2001.0              51.39   58.20     62.91    55.35
# 2002.0              49.44   58.98     63.10    54.63
# 2003.0              52.41   58.59     63.87    53.92
# 2004.0              53.93   59.79     67.24    54.13
# 2005.0              54.91   60.06     67.44    54.99
# 2006.0              56.05   60.30     64.94    56.78
# 2007.0              56.38   60.23     66.44    58.85
# 2008.0              56.09   60.87     66.69    60.25
# 2009.0              55.94   60.30     67.19    60.69
# 2010.0              55.94   59.79     65.83    60.80
# 2011.0              56.47   59.24     66.02    61.71
# 2012.0              56.31   59.72     69.40    61.16
# 2013.0              56.12   59.74     68.16    60.70
# 2014.0              55.51   59.68     66.03    61.09
# 2015.0              55.55   58.69     66.40    60.08
# 2016.0              55.56   56.42     66.62    59.59
# 2017.0              55.57   55.88     67.25    59.13
# 2018.0              54.76   55.92     67.32    59.21
# 2019.0              54.33   55.99     67.46    59.33
# 2020.0              54.10   56.13     67.57    59.45
# 2021.0              54.02   56.15     67.59    59.51
# 2022.0              53.90   56.07     67.51    59.58

# %%
emprego_mercosul.columns = ["Argentina","Brazil", "Paraguay", "Uruguay"]
emprego_mercosul = emprego_mercosul.loc[[2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018]]

# %%
print(emprego_mercosul.corr())
# Out:
#            Argentina    Brazil  Paraguay   Uruguay
# Argentina   1.000000  0.157815  0.661069  0.733213
# Brazil      0.157815  1.000000 -0.023467 -0.010358
# Paraguay    0.661069 -0.023467  1.000000  0.483375
# Uruguay     0.733213 -0.010358  0.483375  1.000000

# %% [markdown]
# ## País 1 x País 2

# %%
emprego_mercosul.plot.scatter(x = "Brazil", y = "Argentina")

# %%
emprego_mercosul.plot.scatter(x = "Brazil", y = "Paraguay")

# %%
emprego_mercosul.plot.scatter(x = "Brazil", y = "Uruguay")

# %%
emprego_mercosul.plot.scatter(x = "Paraguay", y = "Argentina")

# %%
emprego_mercosul.plot.scatter(x = "Paraguay", y = "Uruguay")

# %%
emprego_mercosul.plot.scatter(x = "Uruguay", y = "Argentina")

# %% [markdown]
# ## BRICS

# %%
emprego_brics = emprego.loc[["India", "China", "South Africa", "Russian Federation"]]
emprego_brics = emprego_brics[emprego_brics.Age == "15+"]
emprego_brics.time = emprego_brics.Time.astype(dtype="int64")
emprego_brics
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   This is separate from the ipykernel package so we can avoid doing imports until
#                      Source type  Age  Time        Male      Female  Total
# Reference area
# India               ILO estimate  15+  2000  285569.045   98774.723  55.92
# India               ILO estimate  15+  2001  291961.195  101920.530  56.02
# India               ILO estimate  15+  2002  298473.574  105053.121  56.10
# India               ILO estimate  15+  2003  305449.502  108186.626  56.22
# India               ILO estimate  15+  2004  313265.472  111605.662  56.47
# India               ILO estimate  15+  2005  320869.779  115043.487  56.69
# India               ILO estimate  15+  2006  326593.614  113008.547  55.99
# India               ILO estimate  15+  2007  332272.966  110898.988  55.30
# India               ILO estimate  15+  2008  337116.117  108661.196  54.52
# India               ILO estimate  15+  2009  341045.303  105764.150  53.57
# India               ILO estimate  15+  2010  345860.006  103047.425  52.77
# India               ILO estimate  15+  2011  350231.150   98984.850  51.82
# India               ILO estimate  15+  2012  354258.834   94995.914  50.85
# India               ILO estimate  15+  2013  359857.753   97365.354  50.78
# India               ILO estimate  15+  2014  366028.941   99912.578  50.80
# India               ILO estimate  15+  2015  371679.481  102331.812  50.76
# India               ILO estimate  15+  2016  377197.224  104975.778  50.71
# India               ILO estimate  15+  2017  382806.140  107684.288  50.72
# India               ILO estimate  15+  2018  388879.151  108583.468  50.60
# India               ILO estimate  15+  2019  394987.037  109454.679  50.49
# India               ILO estimate  15+  2020  401196.300  110330.512  50.37
# India               ILO estimate  15+  2021  406845.481  111082.738  50.25
# India               ILO estimate  15+  2022  412728.621  111842.163  50.13
# China               ILO estimate  15+  2000  395360.235  326809.751  74.67
# China               ILO estimate  15+  2001  396335.539  326883.518  73.59
# China               ILO estimate  15+  2002  398372.946  327797.858  72.51
# China               ILO estimate  15+  2003  400763.156  328949.107  71.41
# China               ILO estimate  15+  2004  405339.638  331295.963  70.73
# China               ILO estimate  15+  2005  409068.936  332851.935  70.08
# China               ILO estimate  15+  2006  412557.849  334136.341  69.58
# ...                          ...  ...   ...         ...         ...    ...
# South Africa        ILO estimate  15+  2016    9016.328    6927.323  40.19
# South Africa        ILO estimate  15+  2017    9120.673    7151.684  40.40
# South Africa        ILO estimate  15+  2018    9308.557    7273.899  40.56
# South Africa        ILO estimate  15+  2019    9398.235    7323.308  40.31
# South Africa        ILO estimate  15+  2020    9499.526    7378.060  40.12
# South Africa        ILO estimate  15+  2021    9601.616    7433.120  39.93
# South Africa        ILO estimate  15+  2022    9732.667    7549.991  39.97
# Russian Federation  ILO estimate  15+  2000   33812.784   31786.611  54.81
# Russian Federation  ILO estimate  15+  2001   33744.956   31849.482  54.63
# Russian Federation  ILO estimate  15+  2002   34331.268   32949.030  55.79
# Russian Federation  ILO estimate  15+  2003   34111.134   32831.103  55.27
# Russian Federation  ILO estimate  15+  2004   34534.337   33404.748  55.89
# Russian Federation  ILO estimate  15+  2005   34983.737   33997.815  56.62
# Russian Federation  ILO estimate  15+  2006   35010.420   34368.318  56.90
# Russian Federation  ILO estimate  15+  2007   35988.461   35173.822  58.31
# Russian Federation  ILO estimate  15+  2008   36476.012   35041.994  58.59
# Russian Federation  ILO estimate  15+  2009   35447.534   34502.388  57.33
# Russian Federation  ILO estimate  15+  2010   35942.954   34578.462  57.88
# Russian Federation  ILO estimate  15+  2011   36347.524   34950.765  58.61
# Russian Federation  ILO estimate  15+  2012   36718.268   35174.752  59.30
# Russian Federation  ILO estimate  15+  2013   36635.900   34807.902  59.19
# Russian Federation  ILO estimate  15+  2014   36673.075   34738.360  59.43
# Russian Federation  ILO estimate  15+  2015   36516.409   34331.154  59.20
# Russian Federation  ILO estimate  15+  2016   36430.987   34249.664  59.36
# Russian Federation  ILO estimate  15+  2017   36203.184   33985.226  59.16
# Russian Federation  ILO estimate  15+  2018   36041.030   33830.535  59.06
# Russian Federation  ILO estimate  15+  2019   35765.996   33560.296  58.76
# Russian Federation  ILO estimate  15+  2020   35469.148   33293.041  58.47
# Russian Federation  ILO estimate  15+  2021   34991.725   32907.799  57.85
# Russian Federation  ILO estimate  15+  2022   34511.358   32554.467  57.31
#
# [92 rows x 6 columns]

# %%
emprego_brics = emprego_brics.pivot_table(values='Total', index=emprego_brics.index, columns='Time', aggfunc='first')
emprego_brics
# Out:
# Time                 2000   2001   2002   2003   2004   2005   2006   2007  \
# Reference area
# China               74.67  73.59  72.51  71.41  70.73  70.08  69.58  69.19
# India               55.92  56.02  56.10  56.22  56.47  56.69  55.99  55.30
# Russian Federation  54.81  54.63  55.79  55.27  55.89  56.62  56.90  58.31
# South Africa        39.15  38.82  37.32  36.75  37.18  38.55  39.69  40.19
#
# Time                 2008   2009  ...     2013   2014   2015   2016   2017  \
# Reference area                    ...
# China               68.57  68.09  ...    67.18  66.95  66.68  66.42  66.16
# India               54.52  53.57  ...    50.78  50.80  50.76  50.71  50.72
# Russian Federation  58.59  57.33  ...    59.19  59.43  59.20  59.36  59.16
# South Africa        43.26  41.29  ...    40.15  40.13  40.90  40.19  40.40
#
# Time                 2018   2019   2020   2021   2022
# Reference area
# China               65.68  65.18  64.68  64.15  63.66
# India               50.60  50.49  50.37  50.25  50.13
# Russian Federation  59.06  58.76  58.47  57.85  57.31
# South Africa        40.56  40.31  40.12  39.93  39.97
#
# [4 rows x 23 columns]

# %%
emprego_brics.loc["India",[2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018]].plot.line(grid = True)

# %%
emprego_brics.loc["China",[2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018]].plot.line(grid = True)

# %%
emprego_brics.loc["Russian Federation",[2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018]].plot.line(grid = True)

# %%
emprego_brics.loc["South Africa",[2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018]].plot.line(grid = True)

# %% [markdown]
# ## Conclusão

# %% [markdown]
# Com exceção do Brasil, os países participante do MERCOSUL apresentam um certo grau de covariância entre si durante o período de integração e suspensão da Venezuela no bloco econômico.
